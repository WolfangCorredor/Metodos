# %%
import matplotlib.pyplot as plt

valores = []
funcion1 = [] 
funcion2 = []
matriz = []
aux =[]
aux2 =[]

import matplotlib.pyplot as plt

valores = []
funcion1 = [] 
funcion2 = []
matriz = []

def ingreso():
    print "\nA)" 
    for x in range(0,2):
        ec = x+1
        print ("Ecuacion %s" %(ec))
        matriz.append([])
        for y in range(0,3):
            if y==2:
                val = float(input("B ="))
                matriz[x].append(val)
            else:
                pos=y+1
                val = float(input("X%s ="  %(pos)))
                matriz[x].append(val)
        print matriz[x][0],"X1+",matriz[x][1],"X2=",matriz[x][2]
        
def funtion():
    if matriz[1][0] < matriz[0][0]:
        if matriz[1][0] == 1:
            punto1=((-matriz[0][0]*matriz[1][2])+matriz[0][2])/((-matriz[0][0]*matriz[1][1])+matriz[0][1])
        else:
            punto1=((-matriz[0][0]*(matriz[1][2]/matriz[1][0]))+matriz[0][2])/((-matriz[0][0]*(matriz[1][1]/matriz[1][0]))+matriz[0][1])
        punto2=(matriz[0][2]-(matriz[0][1]*punto1))/matriz[0][0]
    if matriz[1][0] > matriz[0][0]:
        if matriz[0][0] == 1:
            punto1=((-matriz[1][0]*matriz[0][2])+matriz[1][2])/((-matriz[1][0]*matriz[0][1])+matriz[1][1])
        else:
            punto1=((-matriz[1][0]*(matriz[0][2]/matriz[0][0]))+matriz[1][2])/((-matriz[1][0]*(matriz[0][1]/matriz[0][0]))+matriz[1][1])
        punto2=(matriz[1][2]-(matriz[1][1]*punto1))/matriz[1][0]
    print "\nLa solucion para X2= ",punto1
    print "La solucion para X1= ",punto2
    
    if int(punto1) < 10:
        a = 10
    if int(punto1) > 10:
        a = int(punto1)+10
    if int(punto1) > 100:
        a = int(punto1)+100
    if int(punto2) < 10:
        b = 10
    if int(punto2) > 10:
        b = int(punto2)+10
    if int(punto2) > 100:
        b = int(punto2)+100
    if a < b:
        tam = b
    else:
        tam = a
    
    for i in range (tam):
        x2=(-(matriz[0][0]/matriz[0][1])*i)+(matriz[0][2]/matriz[0][1])
        x2b=(-(matriz[1][0]/matriz[1][1])*i)+(matriz[1][2]/matriz[1][1])
        valores.append(i)
        funcion1.append(x2)
        funcion2.append(x2b)
        
    plt.title("Sistema de ecuaciones")
    plt.grid(True)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.plot(valores, funcion1, 'g-', linewidth=1.5)
    plt.plot(valores, funcion2, 'r-',linewidth=1.5)
    plt.plot(punto2,punto1, 'bo')
    plt.show()

    
    ecuacion1=matriz[0][0]*punto2+matriz[0][1]*punto1
    print "El resultado de la primera ecuacion es: %d" %ecuacion1
    ecuacion2=matriz[1][0]*punto2+matriz[1][1]*punto1
    print "El resultado de la segunda ecuacion es: %d" %ecuacion2




def det(num1,num2,num3,num4):
    #det=matr[]
    num = num1*num4-num2*num3
    return num

def elimincognitas():
    x1=det(matriz[0][2],matriz[0][1],matriz[1][2],matriz[1][1])/det(matriz[0][0],matriz[0][1],matriz[1][0],matriz[1][1])
    x2=det(matriz[0][0],matriz[0][2],matriz[1][0],matriz[1][2])/det(matriz[0][0],matriz[0][1],matriz[1][0],matriz[1][1])
    print "\nD)Valores por eliminacion de incognitas  \nValor X1= ",x1
    print "Valor X2= ",x2
    
def a():    
    ingreso()
    funtion()
    
def b():
    print "\nB) SE ESPERA QUE EL DESARROLLO GRAFICO SEA APROXIMADO AL RESULTADO POR SUSTITUCION"
    
def c():
    print "\nC) DETERMINANTE= ",det(matriz[0][0],matriz[0][1],matriz[1][0],matriz[1][1])
def d():
    elimincognitas()
   
a()
b()
c()
d()
# Out:
# A)
# Ecuacion 1
# X1 =-1.1
# X2 =10
# B =120
# -1.1 X1+ 10.0 X2= 120.0
# Ecuacion 2
# X1 =-2
# X2 =17.4
# B =174
# -2.0 X1+ 17.4 X2= 174.0
#
# La solucion para X2=  56.511627907
# La solucion para X1=  404.651162791
# El resultado de la primera ecuacion es: 120
# El resultado de la segunda ecuacion es: 174
#
# B) SE ESPERA QUE EL DESARROLLO GRAFICO SEA APROXIMADO AL RESULTADO POR SUSTITUCION
#
# C) DETERMINANTE=  0.86
#
# D)Valores por eliminacion de incognitas
#   Valor X1=  404.651162791
# Valor X2=  56.511627907
