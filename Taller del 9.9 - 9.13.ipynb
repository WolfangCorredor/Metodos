# %% [markdown]
# 9.9) Use la eliminación de Gauss para resolver el sistema que sigue: 8*X1+2*X2–2*X3=–2; 10*X1+2*X2+4*X3=4; 12*X1+2*X2+2*X3=6. Emplee pivoteo parcial y compruebe las respuestas sustituyéndolas en las ecuaciones originales.

# %%
m,b,x,n,det,factor,tol,s,er = [[8.0,2.0,-2.0],[10.0,2.0,4.0],[12.0,2.0,2.0 ]],[-2.0,4.0,6.0],[],3,1.0,0.0,0.0,[],0.0

for z in range(0,n):
    x.append(n*0.0)
    s.append(n*0.0)
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "X%d = %.1f"%(k,x[i])

def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)


def verificar():

    x1,x2,x3 = x[0],x[1],x[2]
    ecuacion1=8*x1 + 2*x2 - 2*x3
    ecuacion2=10*x1 + 2*x2 + 4*x3
    ecuacion3=12*x1 + 2*x2 + 2*x3
    if (round(ecuacion1)==-2):
        print ("\nSatisface la primera ecuacion")
    if(round(ecuacion2)==4):
        print ("Satisface la segunda ecuacion")
    if(round(ecuacion3)==6):
        print ("Satisface la tercera ecuacion")
        
gauss(m,b,n,x,tol,er)
verificar()
# Out:
# X1 = 1.5
# X2 = -6.5
# X3 = 0.5
#
# Satisface la primera ecuacion
# Satisface la segunda ecuacion
# Satisface la tercera ecuacion

# %% [markdown]
# 9.10 Dado el sistema siguiente de ecuaciones
# –3x2 + 7x3 = 2 x1 + 2x2 – x3 = 3 5x1 – 2x2 = 2
#  a)  Calcule el determinante. b)  Use la regla de Cramer para encontrar cuáles son los valores de las x. c)  Emplee la eliminación de Gauss con pivoteo parcial para obtener cuáles serían los valores de las x.
#  d)  Sustituya sus resultados en las ecuaciones originales para efectos de comprobación.

# %%
#a) Determinante
mtr=[[0.0, -3.0, 7.0], [1.0, 2.0, -1.0], [5.0, -2.0, 0.0]]
solucion=[2.0, 3.0, 2.0]

det=(mtr[0][0]*(mtr[1][1]*mtr[2][2]-mtr[1][2]*mtr[2][1]))-(mtr[0][1]*(mtr[1][0]*mtr[2][2]-mtr[1][2]*mtr[2][0]))+(mtr[0][2]*(mtr[1][0]*mtr[2][1]-mtr[1][1]*mtr[2][0]))
print "\na) El determinante de la matriz de coeficientes es= %d"%det 

d1=(solucion[0]*(mtr[1][1]*mtr[2][2]-mtr[1][2]*mtr[2][1]))-(solucion[1]*(mtr[0][1]*mtr[2][2]-mtr[2][1]*mtr[0][2]))+(solucion[2]*(mtr[0][1]*mtr[1][2]-mtr[1][1]*mtr[0][2]))

d2=-1*(solucion[0]*(mtr[1][0]*mtr[2][2]-mtr[2][0]*mtr[1][2]))+(solucion[1]*(mtr[0][0]*mtr[2][2]-mtr[2][0]*mtr[0][2]))-(solucion[2]*(mtr[0][0]*mtr[1][2]-mtr[1][0]*mtr[0][2]))

d3=(solucion[0]*(mtr[1][0]*mtr[2][1]-mtr[2][0]*mtr[1][1]))-(solucion[1]*(mtr[0][0]*mtr[2][1]-mtr[2][0]*mtr[0][1]))+(solucion[2]*(mtr[0][0]*mtr[1][1]-mtr[1][0]*mtr[0][1]))

x1=d1/det
x2=d2/det
x3=d3/det

print "b)\n    La solución para X1= %f"%x1
print "    La solución para X2= %f"%x2
print "    La solución para X3= %f"%x3

mtrGJ,b,x,n,det,factor,tol,s,er = [[0.0, -3.0, 7.0], [1.0, 2.0, -1.0], [5.0, -2.0, 0.0]],[2.0, 3.0, 2.0],[],3,1.0,0.0,0.0,[],0.0

for z in range(0,n):
    x.append(n*0.0)
    s.append(n*0.0)
        
def eliminar(mtrGJ,s,n,b,tol,er):
    for k in range(0,n):
        pivot(mtrGJ,b,s,n,k)
        if (abs(mtrGJ[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = mtrGJ[i][k]/mtrGJ[k][k]
            for j in range (k+1,n):
                mtrGJ[i][j]=mtrGJ[i][j]-factor*mtrGJ[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(mtrGJ[k][k]/s[k])<tol):
        er=-1
        
def pivotear(mtrGJ,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(mtrGJ[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(mtrGJ[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=mtrGJ[p][j]
            mtrGJ[p][j]=mtrGJ[k][j]
            mtrGJ[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
print ("\nc) Usando Gauss Simple con Pivoteo Parcial:\n")
def sustituir(mtrGJ,n,b,x):
    x[n-1]=b[n-1]/mtrGJ[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*mtrGJ[i][j]
        x[i]=(b[i]-suma)/mtrGJ[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "    X%d = %f"%(k,x[i])

def gauss(mtrGJ,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(mtrGJ[i][1])
        for j in range(1,n):
            if (abs(mtrGJ[i][j])>s[i]):
                s[i]=abs(mtr[i][j])
    eliminar(mtrGJ,s,n,b,tol,er)
    if (er!=-1):
        sustituir(mtrGJ,n,b,x)


def verificar():
    print ("\nd) Verificacion Gauss:\n")
    xA,xB,xC = x[0],x[1],x[2]
    ecuacionA=-3*xB+7*xC
    ecuacionB=xA+2*xB-xC
    ecuacionC=5*xA-2*xB
    if (round(ecuacionA)==2):
        print ("    Satisface la primera ecuacion")
    if(round(ecuacionB)==3):
        print ("    Satisface la segunda ecuacion")
    if(round(ecuacionC)==2):
        print ("    Satisface la tercera ecuacion")
        
gauss(mtrGJ,b,n,x,tol,er)
verificar()

ecuacion1=-3*x2+7*x3
ecuacion2=x1+2*x2-x3
ecuacion3=5*x1-2*x2

print ("\nVerificacion Cramer:\n")
if(ecuacion1==solucion[0]):
    print "    El valor sustituido satisface la ecuacion #1. El resultado es=%d"%ecuacion1
if(ecuacion2==solucion[1]):
    print "    El valor sustituido satisface la ecuacion #2. El resultado es=%d"%ecuacion2
if(round(ecuacion3,1)==solucion[2]):
    print "    El valor sustituido satisface la ecuacion #3. El resultado es=%d"%ecuacion3
# Out:
# a) El determinante de la matriz de coeficientes es= -69
# b)
#     La solución para X1= 0.985507
#     La solución para X2= 1.463768
#     La solución para X3= 0.913043
#
# c) Usando Gauss Simple con Pivoteo Parcial:
#
#     X1 = 0.985507
#     X2 = 1.463768
#     X3 = 0.913043
#
# d) Verificacion Gauss:
#
#     Satisface la primera ecuacion
#     Satisface la segunda ecuacion
#     Satisface la tercera ecuacion
#
# Verificacion Cramer:
#
#     El valor sustituido satisface la ecuacion #1. El resultado es=2
#     El valor sustituido satisface la ecuacion #2. El resultado es=3
#     El valor sustituido satisface la ecuacion #3. El resultado es=2

# %% [markdown]
# 9.11) Dadas las ecuaciones
# 2x1 – 6x2 – x3 = –38 –3x1 – x2 + 7x3 = –34 –8x1 + x2 – 2x3 = –20
#  a)  Resuelva por eliminación de Gauss con pivoteo parcial. Efectúe todos los pasos del cálculo. b)  Sustituya los resultados en las ecuaciones originales para comprobar sus respuestas.

# %%
m,b,x,n,det,factor,tol,s,er = [[2.0,-6.0,-1.0],[-3.0,-1.0,7.0],[-8.0,1.0,-2.0]],[-38.0,-34.0,-20.0],[],3,1.0,0.0,0.0,[],0.0
for z in range(0,n):
    x.append(n*0.0)
    s.append(n*0.0)
        
def eliminar(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivotear(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
print ("\na) Por Gauss Simple con Pivoteo Parcial:")
def sustituir(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "    X%d = %d"%(k,x[i])
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminar(m,s,n,b,tol,er)
    if (er!=-1):
        sustituir(m,n,b,x)

def verificar():
    print ("\nb) Sustituyendo los valores de las incognitas, verificamos que:\n")
    x1,x2,x3 = x[0],x[1],x[2]
    ecuacion1 = round(2*x1 - 6*x2 - x3)
    ecuacion2 = round(-3*x1 - x2 + 7*x3)
    ecuacion3 = round(-8*x1 + x2 - 2*x3)
    if(ecuacion1==-38):
        print ("    Satisface la primera ecuacion. Resultado= "), ecuacion1
    if(ecuacion2==-34):
        print ("    Satisface la segunda ecuacion. Resultado= "), ecuacion2
    if(ecuacion3==-20):
        print ("    Satisface la tercera ecuacion. Resultado= "), ecuacion3
        
gauss(m,b,n,x,tol,er)
verificar()
# Out:
# a) Por Gauss Simple con Pivoteo Parcial:
#     X1 = 4
#     X2 = 8
#     X3 = -2
#
# b) Sustituyendo los valores de las incognitas, verificamos que:
#
#     Satisface la primera ecuacion. Resultado=  -38.0
#     Satisface la segunda ecuacion. Resultado=  -34.0
#     Satisface la tercera ecuacion. Resultado=  -20.0

# %% [markdown]
# 9.12 Emplee la eliminación de Gauss-Jordan para resolver el sistema siguiente:
# 2x1 + x2 – x3 = 1 5x1 + 2x2 + 2x3 = –4 3x1 + x2 + x3 = 5
# No utilice pivoteo. Compruebe sus respuestas con la sustitución en las ecuaciones originales.

# %%
var,piv,matriz = 0,0,[[2.0,1.0,-1.0,1.0],[5.0,2.0,2.0,-4.0],[3.0,1.0,1.0,5.0]]

var = len(matriz[0])-1
    
def cambiar(matriz,piv,var):
    temp=0.0
    temp=matriz[piv][piv]
    for y in range(0,var+1):
        matriz[piv][y]=matriz[piv][y]/temp
        
def ceros(matriz,piv,var):
    for x in range(0,var):
        if (x!=piv):
            c = matriz[x][piv]
            for z in range(0,var+1):
                matriz[x][z]=((-1*c)*matriz[piv][z])+matriz[x][z]
                
for a in range(0,var):
    cambiar(matriz,piv,var)
    ceros(matriz,piv,var)
    piv += 1
for x in range(0,var):
    print "La variable X%d es: %d"%(x+1,matriz[x][var])
    
ecuacion1=2*matriz[0][3]+matriz[1][3]-matriz[2][3]
ecuacion2=5*matriz[0][3]+2*matriz[1][3]+2*matriz[2][3]
ecuacion3=3*matriz[0][3]+matriz[1][3]+matriz[2][3]
print "Satisface la ecuacion 1, su resultado es: ", ecuacion1
print "Satisface la ecuacion 2, su resultado es: ", ecuacion2
print "Satisface la ecuacion 3, su resultado es: ", ecuacion3
# Out:
# La variable X1 es: 14
# La variable X2 es: -32
# La variable X3 es: -5
# Satisface la ecuacion 1, su resultado es:  1.0
# Satisface la ecuacion 2, su resultado es:  -4.0
# Satisface la ecuacion 3, su resultado es:  5.0

# %% [markdown]
# 9.13 Resuelva el sistema:
# x1 + x2 – x3 = –3 6x1 + 2x2 + 2x3 = 2 –3x1 + 4x2 + x3 = 1
# por medio de a) eliminación de Gauss simple, b) eliminación de Gauss con pivoteo parcial, y c) método de Gauss-Jordan sin pivoteo parcial.

# %%
matrizCoef=[[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]]
sol=[-3.0,2.0,1.0]
x,d,y,i,j,k=[],0.0,0.0,0,0,0
n=len(matrizCoef)

for m in range (len(matrizCoef)):
    x.append(0*len(matrizCoef[0]))
print "a) Por metodo de Gauss simple:\n "

for i in range(0,n):
    for j in range(i,n):
        if(i==j):
            d=matrizCoef[i][j]
            for s in range (0,n):
                matrizCoef[i][s]=((matrizCoef[i][s])/d)
            sol[i]=((sol[i])/d)
        else:
            d=matrizCoef[j][i]
            for s in range (0,n):
                matrizCoef[j][s]=matrizCoef[j][s]-(d*matrizCoef[i][s])
            sol[j]=sol[j]-(d*sol[i])
i=n-1
j=n-1

while(i>=0):
    y=sol[i]
    while(j>=i):
        y=y-x[j]*matrizCoef[i][j]
        j-=1
    x[i]=y
    i-=1
    j=n-1
for i in range (0,n):
    k=i+1
    print "El valor de la incognita X%d es %.2f"%(k,x[i])
    
print ("\nb) Por Gauss Simple con Pivoteo Parcial:")
m,b,x,n,factor,tol,s,er = [[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]],[-3.0,2.0,1.0],[],3,0.0,0.0,[],0.0
for z in range(0,n):
    x.append(n*0.0)
    s.append(n*0.0)
        
def eliminar(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivotear(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
        
def sustituir(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print "    X%d = %.2f"%(k,x[i])
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminar(m,s,n,b,tol,er)
    if (er!=-1):
        sustituir(m,n,b,x)

gauss(m,b,n,x,tol,er)

var,piv,matriz = 0,0,[[1.0,1.0,-1.0,-3.0],[6.0,2.0,2.0,2.0],[-3.0,4.0,1.0,1.0]]

var = len(matriz[0])-1
    
def cambiar(matriz,piv,var):
    temp=0.0
    temp=matriz[piv][piv]
    for y in range(0,var+1):
        matriz[piv][y]=matriz[piv][y]/temp
        
def ceros(matriz,piv,var):
    for x in range(0,var):
        if (x!=piv):
            c = matriz[x][piv]
            for z in range(0,var+1):
                matriz[x][z]=((-1*c)*matriz[piv][z])+matriz[x][z]
                
for a in range(0,var):
    cambiar(matriz,piv,var)
    ceros(matriz,piv,var)
    piv += 1
print ("\nc) Gauss Jordan:\n")
for x in range(0,var):
    print "La variable X%d es: %.2f"%(x+1,matriz[x][var])
# Out:
# a) Por metodo de Gauss simple:
#
# El valor de la incognita X1 es -0.25
# El valor de la incognita X2 es -0.50
# El valor de la incognita X3 es 2.25
#
# b) Por Gauss Simple con Pivoteo Parcial:
#     X1 = -0.25
#     X2 = -0.50
#     X3 = 2.25
#
# c) Gauss Jordan:
#
# La variable X1 es: -0.25
# La variable X2 es: -0.50
# La variable X3 es: 2.25
